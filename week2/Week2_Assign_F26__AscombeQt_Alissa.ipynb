# %% [markdown]
# <a href="https://colab.research.google.com/github/Alissa-Ouspen/data110_alissa/blob/main/week2/Week2_Assign_F26__AscombeQt_Alissa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 — In‑Class Python Work & Assignment
# *Prepared: September 12, 2025*
#
# This notebook combines everything covered **in class (Week 2)** and the **assignment** you will submit: run cells top‑to‑bottom, add your answers where prompted, and submit this file.
#
# ### Contents
# 1. [Part A — In‑Class Python Work](#part-a)
# 2. [Part B — Assignment: Anscombe’s Quartet](#part-b)

# %% [markdown]
# ---
#
# <a id='part-a'></a>
#
# ## Part A — In‑Class Python Work

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# The dataset we are using is the World Happiness Report dataset. which can be found in the file https://github.com/Reben80/Data110-21843--fall25/tree/main/dataset

# %%
# Load the dataset but before that we need to download the dataset from the link above and upload it to the colab file
# df = pd.read_csv('/content/happiness_2017.csv')

# or you can just copy the link of the dataset and read as bellow
df = pd.read_csv(
    'https://raw.githubusercontent.com/Reben80/Data110-21843--fall25/refs/heads/main/dataset/happiness.csv')

# %% [markdown]
# ### ***!!   Happiness.csv is different from happiness_2017.csv.***
# ### ***Some variable names are a little different  !!***

# %%
# 1. View the first few rows
# print(df.head())
df.head()  # output is easier to read
# Out:
#        country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 0      Denmark     1            7.693     7.519909           10.699571
# 1       Norway     2            7.655     7.678277           11.050944
# 2  Switzerland     3            7.650     7.776209           10.935776
# 3  Netherlands     4            7.512     7.470716           10.723517
# 4       Sweden     5            7.480     7.560148           10.676098
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.951437                         70.044815
# 1        0.947657                         70.524834
# 2        0.946864                         72.734001
# 3        0.938885                         71.091934
# 4        0.929397                         71.740868
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.932628    0.127539                   0.187408
# 1                      0.946566    0.120922                   0.368043
# 2                      0.945428    0.125727                   0.323241
# 3                      0.877119    0.276100                   0.433754
# 4                      0.944382    0.119244                   0.253543
#
#    Positive affect  Negative affect  Confidence in national government  \
# 0         0.773764         0.208570                           0.534253
# 1         0.822750         0.212821                           0.663341
# 2         0.859107         0.176007                           0.769940
# 3         0.860641         0.226290                           0.574514
# 4         0.855100         0.170226                           0.626497
#
#    Democratic Quality  Delivery Quality  \
# 0            1.294512          2.011580
# 1            1.527817          1.917715
# 2            1.529229          1.879037
# 3            1.396525          1.886310
# 4            1.430478          2.032324
#
#    Standard deviation of ladder by country-year  \
# 0                                      1.702373
# 1                                      1.746018
# 2                                      1.564781
# 3                                      1.351189
# 4                                      1.587887
#
#    Standard deviation/Mean of ladder by country-year  \
# 0                                           0.226382
# 1                                           0.227397
# 2                                           0.201227
# 3                                           0.180865
# 4                                           0.210034
#
#    GINI index (World Bank estimate)  \
# 0                             0.278
# 1                             0.257
# 2                             0.316
# 3                             0.276
# 4                             0.271
#
#    GINI index (World Bank estimate), average 2000-15  \
# 0                                           0.267091
# 1                                           0.271727
# 2                                           0.327571
# 3                                           0.286909
# 4                                           0.267455
#
#    gini of household income reported in Gallup, by wp5-year
# 0                                           0.365274
# 1                                           0.318804
# 2                                           0.308629
# 3                                           0.352454
# 4                                           0.319790

# %%
df.tail()  # last 5 entries
# Out:
#       country  Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# 137   Comoros   138            3.851     3.955640            7.259981
# 138    Guinea   139            3.847     3.651555            7.429011
# 139  Tanzania   140            3.770     4.006897            7.708783
# 140    Rwanda   141            3.715     3.333048            7.318347
# 141     Benin   142            3.528     3.193469            7.526094
#
#      Social support  Healthy life expectancy at birth  \
# 137        0.719218                         53.497059
# 138        0.542295                         48.798191
# 139        0.832056                         53.267857
# 140        0.637147                         54.860779
# 141        0.523027                         50.676147
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 137                      0.534041   -0.069553                   0.651009
# 138                      0.646188    0.011559                   0.794450
# 139                      0.577453    0.206547                   0.886998
# 140                      0.835491   -0.005128                   0.081325
# 141                      0.768971   -0.085358                   0.805978
#
#      Positive affect  Negative affect  Confidence in national government  \
# 137         0.612241         0.211844                           0.464863
# 138         0.677213         0.284573                           0.557172
# 139         0.678828         0.195307                           0.414645
# 140         0.702794         0.132398                                NaN
# 141         0.582524         0.230665                           0.582080
#
#      Democratic Quality  Delivery Quality  \
# 137           -0.459228         -1.185267
# 138           -1.150451         -1.184597
# 139           -0.062280         -0.592592
# 140           -0.754136          0.034556
# 141            0.244427         -0.584024
#
#      Standard deviation of ladder by country-year  \
# 137                                      1.385450
# 138                                      1.659664
# 139                                      1.915126
# 140                                      1.542426
# 141                                      1.640371
#
#      Standard deviation/Mean of ladder by country-year  \
# 137                                           0.350247
# 138                                           0.454509
# 139                                           0.477957
# 140                                           0.462767
# 141                                           0.513664
#
#      GINI index (World Bank estimate)  \
# 137                               NaN
# 138                             0.337
# 139                               NaN
# 140                               NaN
# 141                               NaN
#
#      GINI index (World Bank estimate), average 2000-15  \
# 137                                           0.504500
# 138                                           0.387000
# 139                                           0.384667
# 140                                           0.505500
# 141                                           0.432667
#
#      gini of household income reported in Gallup, by wp5-year
# 137                                           0.428864
# 138                                           0.504480
# 139                                           0.538573
# 140                                           0.616651
# 141                                           0.495051

# %%
# 2. Get summary statistics
# print(df.describe())

df.describe()   # output is easier to read
# Out:
#              Rank  Happiness Score  Life Ladder  Log GDP per capita  \
# count  142.000000       142.000000   142.000000          139.000000
# mean    71.500000         5.467239     5.443751            9.277067
# std     41.135953         1.087999     1.116592            1.149919
# min      1.000000         3.528000     3.164491            6.481236
# 25%     36.250000         4.613750     4.603896            8.409574
# 50%     71.500000         5.346500     5.336502            9.419761
# 75%    106.750000         6.284750     6.210948           10.156146
# max    142.000000         7.693000     7.776209           11.738482
#
#        Social support  Healthy life expectancy at birth  \
# count      142.000000                        140.000000
# mean         0.809077                         62.710796
# std          0.112769                          7.338667
# min          0.510575                         44.032639
# 25%          0.743069                         57.917182
# 50%          0.826323                         64.228752
# 75%          0.903360                         68.048582
# max          0.978965                         75.280479
#
#        Freedom to make life choices  Generosity  Perceptions of corruption  \
# count                    141.000000  132.000000                 132.000000
# mean                       0.711235   -0.006916                   0.757945
# std                        0.152376    0.168477                   0.184070
# min                        0.314565   -0.310992                   0.081325
# 25%                        0.602419   -0.146891                   0.709277
# 50%                        0.705815   -0.033121                   0.806186
# 75%                        0.841320    0.092547                   0.886088
# max                        0.955596    0.625392                   0.961589
#
#        Positive affect  Negative affect  Confidence in national government  \
# count       142.000000       142.000000                         123.000000
# mean          0.706998         0.260280                           0.450038
# std           0.116361         0.091541                           0.172832
# min           0.422928         0.095490                           0.126219
# 25%           0.608709         0.194460                           0.323770
# 50%           0.714799         0.250226                           0.431584
# 75%           0.810865         0.318461                           0.575632
# max           0.916801         0.704590                           0.921518
#
#        Democratic Quality  Delivery Quality  \
# count          138.000000        138.000000
# mean            -0.138336         -0.001194
# std              0.917779          0.994737
# min             -2.263247         -1.555728
# 25%             -0.801834         -0.756355
# 50%             -0.261699         -0.215695
# 75%              0.710391          0.757829
# max              1.529229          2.059123
#
#        Standard deviation of ladder by country-year  \
# count                                    142.000000
# mean                                       1.978302
# std                                        0.318074
# min                                        1.149778
# 25%                                        1.758901
# 50%                                        1.965414
# 75%                                        2.172267
# max                                        2.840633
#
#        Standard deviation/Mean of ladder by country-year  \
# count                                         142.000000
# mean                                            0.378794
# std                                             0.098156
# min                                             0.180865
# 25%                                             0.319020
# 50%                                             0.366049
# 75%                                             0.444032
# max                                             0.792611
#
#        GINI index (World Bank estimate)  \
# count                         73.000000
# mean                           0.360904
# std                            0.077947
# min                            0.247000
# 25%                            0.298000
# 50%                            0.349000
# 75%                            0.414000
# max                            0.574000
#
#        GINI index (World Bank estimate), average 2000-15  \
# count                                         124.000000
# mean                                            0.382938
# std                                             0.083315
# min                                             0.228833
# 25%                                             0.319975
# 50%                                             0.367500
# 75%                                             0.430250
# max                                             0.626000
#
#        gini of household income reported in Gallup, by wp5-year
# count                                         139.000000
# mean                                            0.432619
# std                                             0.107649
# min                                             0.237146
# 25%                                             0.357457
# 50%                                             0.412398
# 75%                                             0.493206
# max                                             0.884414

# %%
# 3. Check the shape (rows, columns)
print(df.shape)

# 142 rows, 20 columns
# Out:
# (142, 20)

# %%
# 4. View column names
print(df.columns)
# Out:
# Index(['country', 'Rank', 'Happiness Score', 'Life Ladder',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government',
#        'Democratic Quality', 'Delivery Quality',
#        'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-15',
#        'gini of household income reported in Gallup, by wp5-year'],
#       dtype='object')

# %%
# 5. Get data types and info
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   country                                                   142 non-null    object
#  1   Rank                                                      142 non-null    int64
#  2   Happiness Score                                           142 non-null    float64
#  3   Life Ladder                                               142 non-null    float64
#  4   Log GDP per capita                                        139 non-null    float64
#  5   Social support                                            142 non-null    float64
#  6   Healthy life expectancy at birth                          140 non-null    float64
#  7   Freedom to make life choices                              141 non-null    float64
#  8   Generosity                                                132 non-null    float64
#  9   Perceptions of corruption                                 132 non-null    float64
#  10  Positive affect                                           142 non-null    float64
#  11  Negative affect                                           142 non-null    float64
#  12  Confidence in national government                         123 non-null    float64
#  13  Democratic Quality                                        138 non-null    float64
#  14  Delivery Quality                                          138 non-null    float64
#  15  Standard deviation of ladder by country-year              142 non-null    float64
#  16  Standard deviation/Mean of ladder by country-year         142 non-null    float64
#  17  GINI index (World Bank estimate)                          73 non-null     float64
#  18  GINI index (World Bank estimate), average 2000-15         124 non-null    float64
#  19  gini of household income reported in Gallup, by wp5-year  139 non-null    float64
# dtypes: float64(18), int64(1), object(1)
# memory usage: 22.3+ KB
# None

# %% [markdown]
# ### Unique values

# %%
# 6. Count unique values in the 'Country' column (or any other relevant column)
print(df['country'].value_counts())   # lower case

df["GINI index (World Bank estimate)"].value_counts()
# Out:
# country
# Denmark        1
# Norway         1
# Switzerland    1
# Netherlands    1
# Sweden         1
#               ..
# Comoros        1
# Guinea         1
# Tanzania       1
# Rwanda         1
# Benin          1
# Name: count, Length: 142, dtype: int64
# GINI index (World Bank estimate)
# 0.422    3
# 0.305    3
# 0.325    2
# 0.271    2
# 0.316    2
#         ..
# 0.409    1
# 0.298    1
# 0.392    1
# 0.427    1
# 0.337    1
# Name: count, Length: 61, dtype: int64

# %%
plt.figure(figsize=(16,10))
plt.scatter(df['Rank'], df['Happiness Score'])  # separated by space in this file

# %%
plt.figure(figsize=(10, 4))
plt.scatter(df["Rank"], df["Social support"],
            color = "red",
            marker = "o",
            edgecolors = "blue",
            s = 20,     # size
            alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"


plt.xlabel("Rank")
plt.ylabel("Social support")
plt.title("Rank vs Social support")
plt.grid(True, linestyle = "--", alpha = 0.8)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("ggplot")   # use this style going forward

# %%
# uses ggplot style

plt.figure(figsize=(10, 4))
plt.scatter(df["Rank"], df["Social support"],
            color = "red",
            marker = "o",
            edgecolors = "blue",
            s = 20,     # size
            alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"


plt.xlabel("Rank")
plt.ylabel("Social support")
plt.title("Rank vs Social support")
plt.grid(True, linestyle = "--", alpha = 0.8)
plt.show()

# %% [markdown]
# ### Example 1: Happiness Score vs. Log GDP per Capita

# %%
# Scatter plot of Happiness Score vs Log GDP per Capita
plt.scatter(df['Log GDP per capita'], df['Happiness Score'])
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Log GDP per Capita')
plt.show()

# %% [markdown]
# ### Example 2: Happiness Score vs. Healthy Life Expectancy

# %%
# Scatter plot of Happiness Score vs Healthy Life Expectancy at Birth
plt.scatter(df['Healthy life expectancy at birth'], df['Happiness Score'], color='green')
plt.xlabel('Healthy Life Expectancy at Birth')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Healthy Life Expectancy at Birth')
plt.show()

# %% [markdown]
# ###  Tasks:
# - **Happiness Score vs Social Support** (`Social support`)
# - **Happiness Score vs Freedom to Make Life Choices** (`Freedom to make life choices`)
# - **Happiness Score vs Generosity** (`Generosity`)
#
# Update your code using the correct column names based on this.
#
# ### Extra Task:
# Create **two scatter plots** using columns that do not have a meaningful relationship. For example, you might plot **Generosity** against **Healthy Life Expectancy**.

# %%
# Your code related to Happiness Score vs Social Support (Social support) need to be here

plt.figure(figsize=(10, 4))
plt.scatter(df["Happiness Score"], df["Social support"],
            #color = "red",
            #marker = "o",
            edgecolors = "blue",  # edge of the circle marker
            #s = 20,     # size
            #alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"


plt.xlabel("Happiness Score")
plt.ylabel("Social support")
plt.title("Happiness Score vs Social support")
plt.grid(True, linestyle = "--")
plt.show()

# %%
# Your code related to Happiness Score vs Freedom to Make Life Choices (Freedom to make life choices) need to be here

plt.figure(figsize=(10, 4))
plt.scatter(df["Happiness Score"], df["Freedom to make life choices"],
            #color = "red",
            marker = "x",
            #edgecolors = "blue",
            #s = 20,     # size
            #alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"


plt.xlabel("Happiness Score")
plt.ylabel("Freedom to Make Life Choices")
plt.title("Happiness Score vs Freedom to Make Life Choices")
plt.grid(True)
plt.show()

# %%
# Your code related to Happiness Score vs Generosity (Generosity) need to be here

plt.figure(figsize=(10, 4))
plt.scatter(df["Happiness Score"], df["Generosity"],
            color = "blue",
            marker = "d",
            #edgecolors = "blue",
            #s = 20,     # size
            #alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"

plt.xlabel("Happiness Score")
plt.ylabel("Generosity")
plt.title("Happiness Score vs Generosity")
plt.grid(True)
plt.show()

# %%
# Extra Task 1 code
# plot Generosity against Healthy Life Expectancy.
plt.figure(figsize=(10, 4))
plt.scatter(df["Healthy life expectancy at birth"], df["Generosity"],
            color = "blue",
            marker = "o",
            #edgecolors = "blue",
            #s = 20,     # size
            #alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"

plt.xlabel("Healthy Life Expectancy")
plt.ylabel("Generosity")
plt.title("Healthy Life Expectancy vs Generosity")
plt.grid(True)
plt.show()

# %%
# Extra Task 2 code

plt.figure(figsize=(10, 4))
plt.scatter(df["Rank"], df["Generosity"],
            color = "blue",
            marker = "o",
            #edgecolors = "blue",
            #s = 20,     # size
            #alpha = 0.9   # trasparency
            )
# "d" = diamond, "o" = circle, "x"

plt.xlabel("Rank")
plt.ylabel("Generosity")
plt.title("Rank vs Generosity")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# <a id='part-b'></a>
#
# ## Part B — Assignment: Anscombe’s Quartet

# %% [markdown]
# ### Step 1: Import Necessary Packages
#
# Before we begin, we need to import the necessary Python libraries for plotting and performing the regression. We'll use:
#
# - `matplotlib.pyplot` for creating the graph
# - `numpy` for numerical operations

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 2: Anscombe's Quartet Dataset
#
# This dataset is known as **Anscombe's Quartet**, created by statistician Francis Anscombe to illustrate the importance of visualizing data. Despite having nearly identical statistical properties (e.g., mean, variance, correlation, and linear regression), each dataset tells a very different story when graphed.
#
# - **x**: The independent variable, common across three datasets.
# - **y1, y2, y3**: Three different dependent variables associated with the same `x` values.
# - **x4, y4**: A special case where most of the `x` values are identical, with one outlier.
#
# #### Anscombe's Quartet:
#
# `

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y1)

# %%
# Calculate the slope (m) and intercept (b) of the line using np.polyfit
m, b = np.polyfit(x, y1, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y1)
plt.plot(x, regression_line, color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %% [markdown]
# ### Your Task:
#
# Perform the same linear regression process for the following datasets: y2, y3, and y4.
# Modify the code to calculate and plot the regression lines for each of these datasets.
# Use distinct colors for each plot and appropriately label the axes (y2, y3, etc.).
# Discuss any differences you observe when comparing the results across all datasets.

# %%
# Your Code need to be here for x and y2

m, b = np.polyfit(x, y2, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y2, color='blue')
plt.plot(x, regression_line, color='red')
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
# Your Code need to be here for x and y3

m, b = np.polyfit(x, y3, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y3, color='green')
plt.plot(x, regression_line, color='red')
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
# Your code need to be here for x and y4

m, b = np.polyfit(x, y4, 1)

# Create the regression line
regression_line = m * np.array(x) + b

# Plot the data points and regression line
plt.scatter(x, y4, color='purple')
plt.plot(x, regression_line, color='red')
plt.xlabel('x')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %%
# Your code need to be here for x4 and y4

m, b = np.polyfit(x4, y4, 1)

# Create the regression line for the original data
regression_line = m * np.array(x4) + b

# Plot the data points and regression line
plt.scatter(x4, y4, color='orange')
plt.plot(x4, regression_line, color='red')

# Create x-values for extrapolation from 4 to 20
x_extrapolated = np.linspace(4, 20, 100) # 100 points for a smooth line

# Calculate corresponding y-values for the extrapolated line
y_extrapolated = m * x_extrapolated + b

# Plot the extrapolated dashed line
plt.plot(x_extrapolated, y_extrapolated, color='red', linestyle='--', alpha=0.7, label='Extrapolated Fit')

plt.xlim(left=4)
plt.xlabel('x4')
plt.ylabel('y4')
plt.legend()
plt.show()

# %% [markdown]
# ### Reflection Question:
#
# After visualizing the linear regression for all four datasets in Anscombe's Quartet, reflect on the following:
#
# #### What is your reflection?
# - How do the datasets visually differ despite having similar summary statistics?
# - How did the outlier in the `x4, y4` dataset affect the regression line compared to the other datasets?
# - Why is it important to visualize data in addition to calculating summary statistics?
#
# Please provide your insights and discuss the importance of data visualization in understanding relationships between variables.

# %% [markdown]
# ### Responses
#
# The regression lines for x vs y1, y2, and y3 all had the same, positive, slope and intercept.
#
# The line for x vs y4 was negative.
#
# The line for x4 vs y4 was the same slope and intercept than the first three scatterplots, but the data is obviously completely different.  The point is made that one outlier can create the illusion of a relationship that is not there.

# %% [markdown]
# ---
#
# **Submission Reminder**
#
# - Before submitting, restart the kernel and run **Run All** to ensure a clean, reproducible output.
# - Save as `Week2_yourname_Assignment.ipynb`.
# - Upload to the designated location in MS Teams / GitHub as instructed.
